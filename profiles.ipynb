# %%
import pandas as pd
import os

from fontTools.misc.cython import returns

BASE_DIR = "data/"
df = pd.read_excel(os.path.join(BASE_DIR, "raw", "FDP JANV.xlsx"), skiprows=1)

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title=" FDP JANV Report")
profile.to_notebook_iframe()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.head()

# %%
#
df.tail(12)

# %%
df.columns

# %%
df.isnull().sum()

# %%
df.isnull().any(axis=1)

# %%
df.duplicated().sum()

# %%
for col in df.columns:
    n_doubloons = df[col].duplicated().sum()
    print(f" '{col}' : {n_doubloons} ")

# %%
for col in df.columns:
    null_col = df[col].isnull().sum()
    print(f" '{col}' : {null_col} ")

# %%
import pandas as pd
import os

BASE_DIR = "data/"
df_BEFR = pd.read_excel(os.path.join(BASE_DIR, "raw", "MAIL BEFR.xlsx"))
df_FR = pd.read_excel(os.path.join(BASE_DIR, "raw", "MAIL FR.xlsx"))
df_AR = pd.read_excel(os.path.join(BASE_DIR, "raw", "MAILS ARCHIVES.xlsx"))

# %%
df_BEFR.info()
df_BEFR.describe()

# %%
####checking doublons for ticket for each agent on FR BEFR
checking_col = ['Numéro de la requête', 'Créé par: Nom complet']
df_doublons = df_FR[df_FR.duplicated(subset=checking_col, keep=False)]
print(df_FR.duplicated(subset=checking_col).sum())
df_doublons.sort_values(by='Numéro de la requête').head(20)

# %%
df_FR.info()
df_FR.describe()

# %%
df_AR.info()
df_AR.describe()

# %%
df_FR.head()

# %%
df_FR.tail(5)

# %%
df_BEFR.head()
df_BEFR.tail(10)

# %%
df_AR.head()

# %%
df_AR.tail(10)

# %%
import pandas as pd
import os

BASE_DIR = "data/"
df_csat = pd.read_excel(os.path.join(BASE_DIR, "raw", "CSAT SRP.xlsx"))

# %%
df_csat.info()

# %%
df_csat.describe()

# %%
import pandas as pd
import os

BASE_DIR = "data/"
df_eval_raw = pd.read_excel(os.path.join(BASE_DIR, "raw", "EVAL SRP.xlsx"))

# %%
df_eval_raw.info()

# %%
df_eval_raw.describe()

# %%
df_eval_raw.head()

# %%
import pandas as pd
import os

BASE_DIR = "data/"
df_CASE_raw = pd.read_excel(os.path.join(BASE_DIR, "raw", "CLOSED CASE.xlsx"))

# %%
df_CASE_raw.describe()

# %%
df_CASE_raw.tail()

# %%
df_CASE_raw.info()

# %%
import pandas as pd
import os

BASE_DIR = "data/"
df_raw = pd.read_csv(os.path.join(BASE_DIR, "tmp", "processed_eval.csv"))

# %%
df_raw.info()

# %%
df_raw.head(88)

# %%
import pandas as pd
import os

BASE_DIR = "data/"

df_BA = pd.read_excel(os.path.join(BASE_DIR, "raw", "BA JANVIER.xlsx"))
df_BO = pd.read_excel(os.path.join(BASE_DIR, "raw", "BATONNAGE BO.xlsx"))
df_PDD = pd.read_excel(os.path.join(BASE_DIR, "raw", "BATONNAGE PDD.xlsx"))
df_RS = pd.read_excel(os.path.join(BASE_DIR, "raw", "BATONNAGE RS.xlsx"))

# %%
df_BA.describe()

# %%
df_BA.info()

# %%
df_BO.info()

# %%
df_PDD.info()

# %%
df_RS.info()
